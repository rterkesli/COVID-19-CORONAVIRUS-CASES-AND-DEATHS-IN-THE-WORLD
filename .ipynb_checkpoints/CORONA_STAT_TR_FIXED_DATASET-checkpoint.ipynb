# %% [markdown]
# # TIME SERIES ANALYSIS ON THE COVID-19 (CORONAVIRUS) CASES AND DEATHS IN THE WORLD VIA A FIXED DATASET(1 JAN 2020-20 MAR 2020)

# %%
#importing relevant libraries
import pandas as pd
import numpy as nd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#I worked on a fixed excel file that was downloaded from EDCD website and regenerated just for the World.
file="covidTR.xlsx"

df=pd.read_excel(
                file, 
                parse_date=[0], #parsing the date is important for the time series analysis
                index_col=0 # This part is seperated date from the columns.
                )
                 
df.head()
# Out:
#             Day  Month  Year  Cases  Deaths Countries and territories GeoId
# DateRep
# 2020-03-23   23      3  2020     10       0               Afghanistan    AF
# 2020-03-22   22      3  2020      0       0               Afghanistan    AF
# 2020-03-21   21      3  2020      2       0               Afghanistan    AF
# 2020-03-20   20      3  2020      0       0               Afghanistan    AF
# 2020-03-19   19      3  2020      0       0               Afghanistan    AF

# %%
type(df.index[0]) #Checking the dates whether they are timestamp or not.
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.info() #general overview on dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6368 entries, 2020-03-23 to 2020-03-21
# Data columns (total 7 columns):
# Day                          6368 non-null int64
# Month                        6368 non-null int64
# Year                         6368 non-null int64
# Cases                        6368 non-null int64
# Deaths                       6368 non-null int64
# Countries and territories    6368 non-null object
# GeoId                        6359 non-null object
# dtypes: int64(5), object(2)
# memory usage: 398.0+ KB

# %%
df.describe() #general descriptive statistics overview on dataset
# Out:
#                Day        Month         Year         Cases       Deaths
# count  6368.000000  6368.000000  6368.000000   6368.000000  6368.000000
# mean     15.459171     2.137249  2019.989479     53.126099     2.293028
# std       8.048945     1.310697     0.102041    403.562845    23.302880
# min       1.000000     1.000000  2019.000000     -9.000000     0.000000
# 25%       9.000000     1.000000  2020.000000      0.000000     0.000000
# 50%      16.000000     2.000000  2020.000000      0.000000     0.000000
# 75%      22.000000     3.000000  2020.000000      3.000000     0.000000
# max      31.000000    12.000000  2020.000000  15141.000000   795.000000

# %%
#We don't need seperate columns for day, month and year. We have already parsed the time in the date column in the begining. 

df=df.drop(columns="Day")
df=df.drop(columns="Month")
df=df.drop(columns="Year")
df.head()
# Out:
#             Cases  Deaths Countries and territories GeoId
# DateRep
# 2020-03-23     10       0               Afghanistan    AF
# 2020-03-22      0       0               Afghanistan    AF
# 2020-03-21      2       0               Afghanistan    AF
# 2020-03-20      0       0               Afghanistan    AF
# 2020-03-19      0       0               Afghanistan    AF

# %% [markdown]
# #### SNAPSHOT ON JANUARY 2020

# %%
df_jan2020=df['2020-01'] #A snapshot for the first month, January 2020
df_jan2020
# Out:
#             Cases  Deaths Countries and territories GeoId
# DateRep
# 2020-01-31      0       0               Afghanistan    AF
# 2020-01-30      0       0               Afghanistan    AF
# 2020-01-29      0       0               Afghanistan    AF
# 2020-01-28      0       0               Afghanistan    AF
# 2020-01-27      0       0               Afghanistan    AF
# 2020-01-26      0       0               Afghanistan    AF
# 2020-01-25      0       0               Afghanistan    AF
# 2020-01-24      0       0               Afghanistan    AF
# 2020-01-23      0       0               Afghanistan    AF
# 2020-01-22      0       0               Afghanistan    AF
# 2020-01-21      0       0               Afghanistan    AF
# 2020-01-20      0       0               Afghanistan    AF
# 2020-01-19      0       0               Afghanistan    AF
# 2020-01-18      0       0               Afghanistan    AF
# 2020-01-17      0       0               Afghanistan    AF
# 2020-01-16      0       0               Afghanistan    AF
# 2020-01-15      0       0               Afghanistan    AF
# 2020-01-14      0       0               Afghanistan    AF
# 2020-01-13      0       0               Afghanistan    AF
# 2020-01-12      0       0               Afghanistan    AF
# 2020-01-11      0       0               Afghanistan    AF
# 2020-01-10      0       0               Afghanistan    AF
# 2020-01-09      0       0               Afghanistan    AF
# 2020-01-08      0       0               Afghanistan    AF
# 2020-01-07      0       0               Afghanistan    AF
# 2020-01-06      0       0               Afghanistan    AF
# 2020-01-05      0       0               Afghanistan    AF
# 2020-01-04      0       0               Afghanistan    AF
# 2020-01-03      0       0               Afghanistan    AF
# 2020-01-02      0       0               Afghanistan    AF
# ...           ...     ...                       ...   ...
# 2020-01-30      0       0                   Vietnam    VN
# 2020-01-29      0       0                   Vietnam    VN
# 2020-01-28      0       0                   Vietnam    VN
# 2020-01-27      0       0                   Vietnam    VN
# 2020-01-26      0       0                   Vietnam    VN
# 2020-01-25      0       0                   Vietnam    VN
# 2020-01-24      2       0                   Vietnam    VN
# 2020-01-23      0       0                   Vietnam    VN
# 2020-01-22      0       0                   Vietnam    VN
# 2020-01-21      0       0                   Vietnam    VN
# 2020-01-20      0       0                   Vietnam    VN
# 2020-01-19      0       0                   Vietnam    VN
# 2020-01-18      0       0                   Vietnam    VN
# 2020-01-17      0       0                   Vietnam    VN
# 2020-01-16      0       0                   Vietnam    VN
# 2020-01-15      0       0                   Vietnam    VN
# 2020-01-14      0       0                   Vietnam    VN
# 2020-01-13      0       0                   Vietnam    VN
# 2020-01-12      0       0                   Vietnam    VN
# 2020-01-11      0       0                   Vietnam    VN
# 2020-01-10      0       0                   Vietnam    VN
# 2020-01-09      0       0                   Vietnam    VN
# 2020-01-08      0       0                   Vietnam    VN
# 2020-01-07      0       0                   Vietnam    VN
# 2020-01-06      0       0                   Vietnam    VN
# 2020-01-05      0       0                   Vietnam    VN
# 2020-01-04      0       0                   Vietnam    VN
# 2020-01-03      0       0                   Vietnam    VN
# 2020-01-02      0       0                   Vietnam    VN
# 2020-01-01      0       0                   Vietnam    VN
#
# [2077 rows x 4 columns]

# %%
total_cases_jan2020 = df_jan2020['Cases'].sum()
print(f"Total Covid-19 cases in January in the World:                            {total_cases_jan2020}")
total_deaths_jan2020 = df_jan2020['Deaths'].sum()
print(f"Total deaths due to Covid-19 cases in January in the World:              {total_deaths_jan2020}")
# Out:
# Total Covid-19 cases in January in the World:                            9799
# Total deaths due to Covid-19 cases in January in the World:              213

# %%
avg_cases_jan2020 = df_jan2020['Cases'].mean()
print(f"Daily average Covid-19 cases in January in the World:                    {avg_cases_jan2020}")
avg_death_jan2020 = df_jan2020['Deaths'].mean()
print(f"Daily average deaths due to Covid-19 cases in January in the World:      {avg_death_jan2020}")
# Out:
# Daily average Covid-19 cases in January in the World:                    4.717862301396244
# Daily average deaths due to Covid-19 cases in January in the World:      0.10255175734232065

# %% [markdown]
# #### SNAPSHOT ON FEBRUARY 2020

# %%
df_feb2020=df['2020-02'] #A snapshot for the second month, February 2020
df_feb2020
# Out:
#             Cases  Deaths Countries and territories GeoId
# DateRep
# 2020-02-29      0       0               Afghanistan    AF
# 2020-02-28      0       0               Afghanistan    AF
# 2020-02-27      0       0               Afghanistan    AF
# 2020-02-26      0       0               Afghanistan    AF
# 2020-02-25      1       0               Afghanistan    AF
# 2020-02-24      0       0               Afghanistan    AF
# 2020-02-23      0       0               Afghanistan    AF
# 2020-02-22      0       0               Afghanistan    AF
# 2020-02-21      0       0               Afghanistan    AF
# 2020-02-20      0       0               Afghanistan    AF
# 2020-02-19      0       0               Afghanistan    AF
# 2020-02-18      0       0               Afghanistan    AF
# 2020-02-17      0       0               Afghanistan    AF
# 2020-02-16      0       0               Afghanistan    AF
# 2020-02-15      0       0               Afghanistan    AF
# 2020-02-14      0       0               Afghanistan    AF
# 2020-02-13      0       0               Afghanistan    AF
# 2020-02-12      0       0               Afghanistan    AF
# 2020-02-11      0       0               Afghanistan    AF
# 2020-02-10      0       0               Afghanistan    AF
# 2020-02-09      0       0               Afghanistan    AF
# 2020-02-08      0       0               Afghanistan    AF
# 2020-02-07      0       0               Afghanistan    AF
# 2020-02-06      0       0               Afghanistan    AF
# 2020-02-05      0       0               Afghanistan    AF
# 2020-02-04      0       0               Afghanistan    AF
# 2020-02-03      0       0               Afghanistan    AF
# 2020-02-02      0       0               Afghanistan    AF
# 2020-02-01      0       0               Afghanistan    AF
# 2020-02-29      0       0                   Algeria    DZ
# ...           ...     ...                       ...   ...
# 2020-02-01      1       0  United_States_of_America    US
# 2020-02-29      0       0                   Vietnam    VN
# 2020-02-28      0       0                   Vietnam    VN
# 2020-02-27      0       0                   Vietnam    VN
# 2020-02-26      0       0                   Vietnam    VN
# 2020-02-25      0       0                   Vietnam    VN
# 2020-02-24      0       0                   Vietnam    VN
# 2020-02-23      0       0                   Vietnam    VN
# 2020-02-22      0       0                   Vietnam    VN
# 2020-02-21      0       0                   Vietnam    VN
# 2020-02-20      0       0                   Vietnam    VN
# 2020-02-19      0       0                   Vietnam    VN
# 2020-02-18      0       0                   Vietnam    VN
# 2020-02-17      0       0                   Vietnam    VN
# 2020-02-16      0       0                   Vietnam    VN
# 2020-02-15      0       0                   Vietnam    VN
# 2020-02-14      0       0                   Vietnam    VN
# 2020-02-13      1       0                   Vietnam    VN
# 2020-02-12      0       0                   Vietnam    VN
# 2020-02-11      1       0                   Vietnam    VN
# 2020-02-10      0       0                   Vietnam    VN
# 2020-02-09      1       0                   Vietnam    VN
# 2020-02-08      1       0                   Vietnam    VN
# 2020-02-07      2       0                   Vietnam    VN
# 2020-02-06      0       0                   Vietnam    VN
# 2020-02-05      1       0                   Vietnam    VN
# 2020-02-04      1       0                   Vietnam    VN
# 2020-02-03      1       0                   Vietnam    VN
# 2020-02-02      2       0                   Vietnam    VN
# 2020-02-01      0       0                   Vietnam    VN
#
# [1943 rows x 4 columns]

# %%
total_cases_feb2020 = df_feb2020['Cases'].sum()
print(f"Total Covid-19 cases in February in the World:                           {total_cases_feb2020}")
total_deaths_feb2020 = df_feb2020['Deaths'].sum()
print(f"Total deaths due to Covid-19 cases in February in the World:              {total_deaths_feb2020}")
# Out:
# Total Covid-19 cases in February in the World:                           75377
# Total deaths due to Covid-19 cases in February in the World:              2708

# %%
avg_cases_feb2020=df_feb2020['Cases'].mean()
print(f"Daily average Covid-19 cases in February in the World:                    {avg_cases_feb2020}")
avg_death_feb2020=df_feb2020['Deaths'].mean()
print(f"Daily average deaths due to Covid-19 cases in February in the World:      {avg_death_feb2020}")
# Out:
# Daily average Covid-19 cases in February in the World:                    38.79413278435409
# Daily average deaths due to Covid-19 cases in February in the World:      1.3937210499227999

# %% [markdown]
# #### SNAPSHOT ON MARCH 2020

# %%
df_mar2020=df['2020-03'] #A snapshot for the third month, March 2020
df_mar2020
# Out:
#             Cases  Deaths Countries and territories GeoId
# DateRep
# 2020-03-23     10       0               Afghanistan    AF
# 2020-03-22      0       0               Afghanistan    AF
# 2020-03-21      2       0               Afghanistan    AF
# 2020-03-20      0       0               Afghanistan    AF
# 2020-03-19      0       0               Afghanistan    AF
# 2020-03-18      1       0               Afghanistan    AF
# 2020-03-17      5       0               Afghanistan    AF
# 2020-03-16      6       0               Afghanistan    AF
# 2020-03-15      3       0               Afghanistan    AF
# 2020-03-11      3       0               Afghanistan    AF
# 2020-03-08      3       0               Afghanistan    AF
# 2020-03-02      0       0               Afghanistan    AF
# 2020-03-01      0       0               Afghanistan    AF
# 2020-03-23      0       0                    Angola    AO
# 2020-03-22      2       0                    Angola    AO
# 2020-03-23     13       0                   Albania    AL
# 2020-03-22      6       0                   Albania    AL
# 2020-03-21      0       0                   Albania    AL
# 2020-03-20     11       0                   Albania    AL
# 2020-03-19      4       1                   Albania    AL
# 2020-03-18      4       0                   Albania    AL
# 2020-03-17      9       0                   Albania    AL
# 2020-03-16      4       0                   Albania    AL
# 2020-03-15      5       0                   Albania    AL
# 2020-03-14     10       0                   Albania    AL
# 2020-03-13     12       0                   Albania    AL
# 2020-03-12      1       1                   Albania    AL
# 2020-03-11      4       0                   Albania    AL
# 2020-03-10      4       0                   Albania    AL
# 2020-03-09      2       0                   Albania    AL
# ...           ...     ...                       ...   ...
# 2020-03-17     18       0                 Venezuela    VE
# 2020-03-16      5       0                 Venezuela    VE
# 2020-03-15     10       0                 Venezuela    VE
# 2020-03-23     24       0                   Vietnam    VN
# 2020-03-22      7       0                   Vietnam    VN
# 2020-03-21      2       0                   Vietnam    VN
# 2020-03-20      9       0                   Vietnam    VN
# 2020-03-19     15       0                   Vietnam    VN
# 2020-03-18      0       0                   Vietnam    VN
# 2020-03-17      4       0                   Vietnam    VN
# 2020-03-16      4       0                   Vietnam    VN
# 2020-03-15      4       0                   Vietnam    VN
# 2020-03-14      5       0                   Vietnam    VN
# 2020-03-13      5       0                   Vietnam    VN
# 2020-03-12      4       0                   Vietnam    VN
# 2020-03-11      4       0                   Vietnam    VN
# 2020-03-10      1       0                   Vietnam    VN
# 2020-03-09      9       0                   Vietnam    VN
# 2020-03-08      4       0                   Vietnam    VN
# 2020-03-07      1       0                   Vietnam    VN
# 2020-03-02      0       0                   Vietnam    VN
# 2020-03-01      0       0                   Vietnam    VN
# 2020-03-23      1       0                    Zambia    ZM
# 2020-03-22      0       0                    Zambia    ZM
# 2020-03-21      0       0                    Zambia    ZM
# 2020-03-20      0       0                    Zambia    ZM
# 2020-03-19      2       0                    Zambia    ZM
# 2020-03-23      0       0                  Zimbabwe    ZW
# 2020-03-22      1       0                  Zimbabwe    ZW
# 2020-03-21      1       0                  Zimbabwe    ZW
#
# [2281 rows x 4 columns]

# %%
total_cases_mar2020 = df_mar2020['Cases'].sum()
print(f"Total Covid-19 cases in March in the World:                           {total_cases_mar2020}")
total_deaths_mar2020 = df_mar2020['Deaths'].sum()
print(f"Total deaths due to Covid-19 cases in March in the World:              {total_deaths_mar2020}")
# Out:
# Total Covid-19 cases in March in the Netherlands:                           253104
# Total deaths due to Covid-19 cases in March in the Netherlands:              11681

# %%
avg_cases_mar2020=df_mar2020['Cases'].mean()
print(f"Daily average Covid-19 cases in March in the World:                    {avg_cases_mar2020}")
avg_death_mar2020=df_mar2020['Deaths'].mean()
print(f"Daily average deaths due to Covid-19 cases in March in the World:      {avg_death_mar2020}")
# Out:
# Daily average Covid-19 cases in March in the World:                    110.9618588338448
# Daily average deaths due to Covid-19 cases in March in the World:      5.1209995615957915

# %% [markdown]
# ### Plots and statistics with Time Series Analysis

# %% [markdown]
# #### WEEKLY(1JAN-20 MAR 2020)

# %%
df.Cases.resample("W").mean() #Weekly average of the Covid-19 Cases in 2020
# Out:
# DateRep
# 2020-01-05      0.146766
# 2020-01-12      0.000000
# 2020-01-19      0.341151
# 2020-01-26      3.846482
# 2020-02-02     26.718550
# 2020-02-09     49.036247
# 2020-02-16     67.618337
# 2020-02-23     20.356077
# 2020-03-01     17.509595
# 2020-03-08     50.264706
# 2020-03-15     76.795953
# 2020-03-22    144.247423
# 2020-03-29    183.511111
# Freq: W-SUN, Name: Cases, dtype: float64

# %%
df.Deaths.resample("W").mean() #Weekly death average in 2020
# Out:
# DateRep
# 2020-01-05    0.000000
# 2020-01-12    0.002132
# 2020-01-19    0.004264
# 2020-01-26    0.113006
# 2020-02-02    0.530917
# 2020-02-09    1.083156
# 2020-02-16    1.825160
# 2020-02-23    1.692964
# 2020-03-01    1.100213
# 2020-03-08    1.620321
# 2020-03-15    3.669477
# 2020-03-22    6.730084
# 2020-03-29    9.222222
# Freq: W-SUN, Name: Deaths, dtype: float64

# %%
df.resample("W").mean().plot() #Line plot weekly basis both cases and deaths due to Covid-19

# %%
df.Deaths.resample("W").mean().plot(kind="bar")#Bar plot weekly just deaths column

# %%
df.Cases.resample("W").mean().plot(kind='bar') #Bar plot weekly just deaths column

# %% [markdown]
# #### SPECIAL FOCUS ON MARCH
# 2020

# %%
df['2020-03'].resample('D').mean().plot(kind='bar') #Daily basis both cases and deaths in bar plot in March 2020

# %%
df['2020-03'].resample('D').mean().plot() #Daily basis both cases and deaths in line plot in March 2020

# %%
df['2020-03'].Deaths.resample("D").mean().plot() #Daily basis just cases in line plot in March 2020

# %%
df['2020-03'].Deaths.resample("D").mean().plot() #Daily basis just deaths in line plot in March 2020

# %%
df['2020-03'].Cases.resample('D').mean().plot(kind='bar') #Daily basis just cases in bar plot in March 2020

# %%
df['2020-03'].Deaths.resample('D').mean().plot(kind='bar') #Daily basis just deaths in bar plot in March 2020
